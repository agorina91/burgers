# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tabula

# %%
mcd = pd.read_csv('/Users/anastasiagorina/Desktop/Projects/burgers/Data/McD.csv')
mcd.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
ss = pd.read_csv('/Users/anastasiagorina/Desktop/Projects/burgers/Data/SS.csv')
ss.head()
# Out:
#                                              Burgers Calories Total Fat  \
# 0  100% all-natural Angus beef. No hormones and n...      NaN       NaN
# 1  proprietary Shack blend is freshly ground and ...      NaN       NaN
# 2                                               bun.      NaN       NaN
# 3                                Single ShackBurger®      530        34
# 4                                Double ShackBurger®      790        52
#
#   Sat Fat Trans Fat Chol. Sodium Total Carb Fiber Sugars Protein
# 0     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 1     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 2     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 3      14         1   115   1260         26     0      6      29
# 4      23         2   195   2280         27     0      6      51

# %%
mcd.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
ss.tail()
# Out:
#                Burgers Calories Total Fat Sat Fat Trans Fat Chol. Sodium  \
# 920  Prosecco (375 ml)      310         0       0         0     0     20
# 921    Scarpetta (6oz)      140         0       0         0     0     10
# 922     Gotham Red Can      210         0       0         0     0     10
# 923   Gotham White Can      200         0       0         0     0     10
# 924    Gotham Rosé Can      210         0       0         0     0     10
#
#     Total Carb Fiber Sugars Protein
# 920         10     0      4       0
# 921          4     0      2       0
# 922          6     0      0       0
# 923          5     0      0       0
# 924          9     0      0       1

# %%
print(mcd.shape)
print(ss.shape)
# Out:
# (260, 24)
# (925, 11)

# %%
ss.dropna(how='all', inplace=True)
ss.head()
# Out:
#                                              Burgers Calories Total Fat  \
# 0  100% all-natural Angus beef. No hormones and n...      NaN       NaN
# 1  proprietary Shack blend is freshly ground and ...      NaN       NaN
# 2                                               bun.      NaN       NaN
# 3                                Single ShackBurger®      530        34
# 4                                Double ShackBurger®      790        52
#
#   Sat Fat Trans Fat Chol. Sodium Total Carb Fiber Sugars Protein
# 0     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 1     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 2     NaN       NaN   NaN    NaN        NaN   NaN    NaN     NaN
# 3      14         1   115   1260         26     0      6      29
# 4      23         2   195   2280         27     0      6      51

# %%
ss.shape
# Out:
# (717, 11)

# %%
ss.dropna(how='any', inplace=True)
ss.head()
# Out:
#                Burgers Calories Total Fat Sat Fat Trans Fat Chol. Sodium  \
# 3  Single ShackBurger®      530        34      14         1   115   1260
# 4  Double ShackBurger®      790        52      23         2   195   2280
# 5     Single Hamburger      400        22      10         1    85    850
# 6     Double Hamburger      590        34      15       1.5   150   1540
# 7  Single Cheeseburger      470        28      14         1   105   1200
#
#   Total Carb Fiber Sugars Protein
# 3         26     0      6      29
# 4         27     0      6      51
# 5         24     0      5      25
# 6         24     0      5      44
# 7         25     0      5      29

# %%
ss.shape
# Out:
# (708, 11)

# %%
ss.to_csv('upd_ss.csv')

# %%
ss.dtypes
# Out:
# Burgers       object
# Calories      object
# Total Fat     object
# Sat Fat       object
# Trans Fat     object
# Chol.         object
# Sodium        object
# Total Carb    object
# Fiber         object
# Sugars        object
# Protein       object
# dtype: object

# %%
mcd.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
mcd.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mcd.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
ss = ss[(ss.Calories != 'Calories') & (ss['Total Fat'] != 'Total Fat') & (ss['Sat Fat'] != 'Sat Fat') & (ss['Trans Fat'] != 'Trans Fat') & (ss['Chol.'] != 'Chol.') & (ss.Sodium != 'Sodium') & (ss['Total Carb'] != 'Total Carb') & (ss['Fiber'] != 'Fiber') & (ss.Sugars != 'Sugars') & (ss.Protein != 'Protein')]

# %%
ss.to_csv('almost_cleaned_ss.csv')

# %%
c_ss = pd.read_csv('/Users/anastasiagorina/Desktop/Projects/burgers/Data/almost_cleaned_ss.csv')
c_ss.drop(columns="Unnamed: 0", inplace=True)
c_ss.head()
# Out:
#                Burgers  Calories  Total Fat  Sat Fat  Trans Fat  Chol.  \
# 0  Single ShackBurger®       530       34.0     14.0        1.0    115
# 1  Double ShackBurger®       790       52.0     23.0        2.0    195
# 2     Single Hamburger       400       22.0     10.0        1.0     85
# 3     Double Hamburger       590       34.0     15.0        1.5    150
# 4  Single Cheeseburger       470       28.0     14.0        1.0    105
#
#    Sodium  Total Carb  Fiber  Sugars  Protein
# 0    1260          26      0       6       29
# 1    2280          27      0       6       51
# 2     850          24      0       5       25
# 3    1540          24      0       5       44
# 4    1200          25      0       5       29

# %%
c_ss.Calories.astype(int)
# Out:
# 0      530
# 1      790
# 2      400
# 3      590
# 4      470
#       ...
# 691    310
# 692    140
# 693    210
# 694    200
# 695    210
# Name: Calories, Length: 696, dtype: int64

# %%
c_ss.dtypes
# Out:
# Burgers        object
# Calories        int64
# Total Fat     float64
# Sat Fat       float64
# Trans Fat     float64
# Chol.           int64
# Sodium          int64
# Total Carb      int64
# Fiber           int64
# Sugars          int64
# Protein         int64
# dtype: object

# %%
c_ss.describe()
# Out:
#           Calories   Total Fat     Sat Fat   Trans Fat       Chol.  \
# count   696.000000  696.000000  696.000000  696.000000  696.000000
# mean    542.409483   28.543103   15.796695    0.331897  137.864943
# std     365.922361   21.428389   12.129664    0.585597  102.982483
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     235.000000    6.000000    3.000000    0.000000   15.000000
# 50%     500.000000   27.000000   15.000000    0.000000  130.000000
# 75%     860.000000   45.000000   25.000000    0.500000  240.000000
# max    2200.000000  140.000000   86.000000    3.000000  520.000000
#
#             Sodium  Total Carb       Fiber      Sugars     Protein
# count   696.000000  696.000000  696.000000  696.000000  696.000000
# mean    443.472701   64.242816    0.354885   50.945402   11.275862
# std     498.867211   56.938159    1.122269   46.060797   10.468386
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
mcd.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
c_ss.to_csv('cleaned_SS_menu.csv')

# %%
c_mcd = mcd[['Item', 'Calories', 'Total Fat', 'Saturated Fat', 'Trans Fat', 'Cholesterol', 'Sodium', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein']]

# %%
c_mcd.to_csv('cleaned_McD_menu.csv')

# %%
c_mcd.describe()
# Out:
#           Calories   Total Fat  Saturated Fat   Trans Fat  Cholesterol  \
# count   260.000000  260.000000     260.000000  260.000000   260.000000
# mean    368.269231   14.165385       6.007692    0.203846    54.942308
# std     240.269886   14.205998       5.321873    0.429133    87.269257
# min       0.000000    0.000000       0.000000    0.000000     0.000000
# 25%     210.000000    2.375000       1.000000    0.000000     5.000000
# 50%     340.000000   11.000000       5.000000    0.000000    35.000000
# 75%     500.000000   22.250000      10.000000    0.000000    65.000000
# max    1880.000000  118.000000      20.000000    2.500000   575.000000
#
#             Sodium  Carbohydrates  Dietary Fiber      Sugars     Protein
# count   260.000000     260.000000     260.000000  260.000000  260.000000
# mean    495.750000      47.346154       1.630769   29.423077   13.338462
# std     577.026323      28.252232       1.567717   28.679797   11.426146
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (10,8))
sns.distplot(c_mcd.Calories)

# %%
plt.figure(figsize = (10,8))
sns.distplot(c_ss.Calories)

# %%
sns.pairplot(c_mcd)

# %%
sns.pairplot(c_ss)

# %%
#comparing distributions of calories
plt.figure(figsize = (10,8))
plt.title('Distribution of calories McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(c_mcd['Calories'], shade=1, color='red')
sns.kdeplot(c_ss['Calories'], shade=1, color='green')

# %%
#comparing distributions of fats
plt.figure(figsize = (10,8))
plt.title('Distribution of total fat McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(c_mcd['Total Fat'], shade=1, color='red')
sns.kdeplot(c_ss['Total Fat'], shade=1, color='green')

# %%
print(c_mcd.columns)
print(c_ss.columns)
# Out:
# Index(['Calories', 'Total Fat', 'Saturated Fat', 'Trans Fat', 'Cholesterol',
#        'Sodium', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein'],
#       dtype='object')
# Index(['Burgers', 'Calories', 'Total Fat', 'Sat Fat', 'Trans Fat', 'Chol.',
#        'Sodium', 'Total Carb', 'Fiber', 'Sugars', 'Protein'],
#       dtype='object')

# %%
#comparing distributions of fiber
plt.figure(figsize = (10,8))
plt.title('Distribution of fiber McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(c_mcd['Dietary Fiber'], shade=1, color='red')
sns.kdeplot(c_ss['Fiber'], bw=1.5, shade=1, color='green')

# %%
#comparing distributions of carbs
plt.figure(figsize = (10,8))
plt.title('Distribution of Carbs McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(c_mcd['Carbohydrates'], shade=1, color='red')
sns.kdeplot(c_ss['Total Carb'], shade=1, color='green')

# %%
from scipy import stats

# %%
from scipy.stats import ttest_1samp

# %%
#Carbs
stats.ttest_ind(c_mcd['Carbohydrates'], c_ss['Total Carb'])
# Out:
# Ttest_indResult(statistic=-4.578041438504688, pvalue=5.313792274965054e-06)

# %%
#Calories
stats.ttest_ind(c_mcd['Calories'], c_ss['Calories'])
# Out:
# Ttest_indResult(statistic=-7.120326456608123, pvalue=2.117448120859828e-12)

# %%
#Fats
stats.ttest_ind(c_mcd['Total Fat'], c_ss['Total Fat'])
# Out:
# Ttest_indResult(statistic=-10.02554185999552, pvalue=1.4701340692512491e-22)

# %%
#Cholesterol
stats.ttest_ind(c_mcd['Cholesterol'], c_ss['Chol.'])
# Out:
# Ttest_indResult(statistic=-11.528163973887171, pvalue=7.040423780743103e-29)

# %%
#Fiber
stats.ttest_ind(c_mcd['Dietary Fiber'], c_ss['Fiber'])
# Out:
# Ttest_indResult(statistic=13.943976705913558, pvalue=2.341114180002528e-40)

# %%
#Sugars
stats.ttest_ind(c_mcd['Sugars'], c_ss['Sugars'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-8.635324573033252, pvalue=3.5588387269635806e-17)

# %%
stats.ttest_ind(c_mcd['Sugars'], c_ss['Sugars'])
# Out:
# Ttest_indResult(statistic=-7.040410739819747, pvalue=3.662358913331169e-12)

# %%
c_ss.head(10)
# Out:
#                Burgers  Calories  Total Fat  Sat Fat  Trans Fat  Chol.  \
# 0  Single ShackBurger®       530       34.0     14.0        1.0    115
# 1  Double ShackBurger®       790       52.0     23.0        2.0    195
# 2     Single Hamburger       400       22.0     10.0        1.0     85
# 3     Double Hamburger       590       34.0     15.0        1.5    150
# 4  Single Cheeseburger       470       28.0     14.0        1.0    105
# 5  Double Cheeseburger       730       46.0     22.0        2.0    185
# 6       ‘Shroom Burger       550       31.0     12.0        0.5     55
# 7         Shack Stack®       800       49.0     21.0        1.5    140
# 8  Single SmokeShackTM       610       39.0     16.0        1.0    130
# 9  Double SmokeShackTM       870       57.0     24.0        2.0    210
#
#    Sodium  Total Carb  Fiber  Sugars  Protein
# 0    1260          26      0       6       29
# 1    2280          27      0       6       51
# 2     850          24      0       5       25
# ...

# %%
c_mcd.head(10)
# Out:
#                                                 Item  Calories  Total Fat  \
# 0                                       Egg McMuffin       300       13.0
# 1                                  Egg White Delight       250        8.0
# 2                                   Sausage McMuffin       370       23.0
# 3                          Sausage McMuffin with Egg       450       28.0
# 4                   Sausage McMuffin with Egg Whites       400       23.0
# 5                               Steak & Egg McMuffin       430       23.0
# 6      Bacon, Egg & Cheese Biscuit (Regular Biscuit)       460       26.0
# 7        Bacon, Egg & Cheese Biscuit (Large Biscuit)       520       30.0
# 8  Bacon, Egg & Cheese Biscuit with Egg Whites (R...       410       20.0
# 9  Bacon, Egg & Cheese Biscuit with Egg Whites (L...       470       25.0
#
#    Saturated Fat  Trans Fat  Cholesterol  Sodium  Carbohydrates  \
# 0            5.0        0.0          260     750             31
# ...

# %%
mcd_b = c_mcd.loc[range(43, 69), :]

# %%
ss_b = c_ss.loc[range(0, 28), :]

# %%
mcd_b
# Out:
#                                           Item  Calories  Total Fat  \
# 43                 Quarter Pounder with Cheese       520       26.0
# 44         Quarter Pounder with Bacon & Cheese       600       29.0
# 45   Quarter Pounder with Bacon Habanero Ranch       610       31.0
# 46                      Quarter Pounder Deluxe       540       27.0
# 47          Double Quarter Pounder with Cheese       750       43.0
# 48                                   Hamburger       240        8.0
# 49                                Cheeseburger       290       11.0
# 50                         Double Cheeseburger       430       21.0
# 51                      Bacon Clubhouse Burger       720       40.0
# 52                                    McDouble       380       17.0
# 53                              Bacon McDouble       440       22.0
# 54                                Daily Double       430       22.0
# 55                             Jalapeño Double       430       23.0
# ...

# %%
ss_b
# Out:
#                                Burgers  Calories  Total Fat  Sat Fat  \
# 0                  Single ShackBurger®       530       34.0     14.0
# 1                  Double ShackBurger®       790       52.0     23.0
# 2                     Single Hamburger       400       22.0     10.0
# 3                     Double Hamburger       590       34.0     15.0
# 4                  Single Cheeseburger       470       28.0     14.0
# 5                  Double Cheeseburger       730       46.0     22.0
# 6                       ‘Shroom Burger       550       31.0     12.0
# 7                         Shack Stack®       800       49.0     21.0
# 8                  Single SmokeShackTM       610       39.0     16.0
# 9                  Double SmokeShackTM       870       57.0     24.0
# 10             Roadside Double Burger*       770       46.0     20.0
# 11               Lockhart Link Burger*       810       60.0     24.0
# 12       Lockhart Link Burger, Double*      1070       78.0     32.0
# ...

# %%
#Burger calories
plt.figure(figsize = (10,8))
plt.title('Distribution of BURGER calories McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(mcd_b['Calories'], shade=1, color='red')
sns.kdeplot(ss_b['Calories'], shade=1, color='green')

# %%
stats.ttest_ind(mcd_b['Calories'], ss_b['Calories'])
# Out:
# Ttest_indResult(statistic=-4.531714851847517, pvalue=3.4596420282065035e-05)

# %%
#Burger carbs
plt.figure(figsize = (10,8))
plt.title('Distribution of BURGER Carbs McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(mcd_b['Carbohydrates'], shade=1, color='red')
sns.kdeplot(ss_b['Total Carb'], shade=1, color='green')

# %%
stats.ttest_ind(mcd_b['Carbohydrates'], ss_b['Total Carb'])
# Out:
# Ttest_indResult(statistic=5.742015221755025, pvalue=4.904624727318318e-07)

# %%
#Burger protein
plt.figure(figsize = (10,8))
plt.title('Distribution of BURGER Proteins McDonalds (red) vs Shake Shack (green)')
sns.kdeplot(mcd_b['Protein'], shade=1, color='red')
sns.kdeplot(ss_b['Protein'], shade=1, color='green')

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text_m = " ".join(word for word in c_mcd.Item)

# %%
stopwords = set(STOPWORDS)
stopwords.update(['Small', 'Medium', 'Large'])

wordcloud = WordCloud(collocations=False, stopwords=stopwords, background_color="White").generate(text_m)

plt.figure(figsize = (16,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_ss = " ".join(word for word in c_ss.Burgers)

# %%
stopwords = set(STOPWORDS)
stopwords.update(['Small', 'Medium', 'Large', 'Double'])

wordcloud = WordCloud(collocations=False, stopwords=stopwords, background_color="White").generate(text_ss)

plt.figure(figsize = (16,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
